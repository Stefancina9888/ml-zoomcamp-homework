# %%
import sys
import numpy as np
import pandas as pd
import sklearn
import matplotlib
import seaborn as sns

print("Python:", sys.version)
print("Putanja:", sys.executable)
print("NumPy:", np.__version__)
print("pandas:", pd.__version__)
print("scikit-learn:", sklearn.__version__)
print("Environment radi!")
# Out:
# Python: 3.11.16 | packaged by Anaconda, Inc. | (main, Aug 27 2026, 14:36:16) [MSC v.1942 64 bit (AMD64)]
# Putanja: c:\Users\iTC\anaconda3\envs\ml-zoomcamp\python.exe
# NumPy: 2.4.6
# pandas: 3.0.5
# scikit-learn: 1.9.0
# Environment radi!
